# %%
import os
import traceback
import yaml
from pathlib import Path
import pandas as pd

total_count = 0

def parse_provider(config, permissions):
    if 'provider' not in config:
        return

    provider = config['provider']

    if not isinstance(provider, dict):
        return

    if 'iam' in provider:
        if 'role' in provider['iam']:
            role = provider['iam']['role']

            if isinstance(role, str):
                return

            if isinstance(role, dict) and 'statements' in role:
                for stmt in role['statements']:
                    if isinstance(stmt, dict):
                        actions = stmt['Action']
                        if isinstance(actions, list):
                            for action in actions:
                                permissions.add(action)

            if 'managedPolicies' in role:
                managedPolicies = role['managedPolicies']
                if isinstance(managedPolicies, list):
                    for policy in managedPolicies:
                        permissions.add(policy)

    elif 'iamRoleStatements' in provider:
        stmts = provider['iamRoleStatements']
        if isinstance(stmts, list):
            for stmt in stmts:
                if isinstance(stmt, dict):
                    actions = stmt['Action']
                    if isinstance(actions, list):
                        for action in actions:
                            permissions.add(action)

def parse_functions(config, permissions):
    if 'functions' not in config:
        return

    functions = config['functions']

    if isinstance(functions, dict):
        for function_name, function in functions.items():
            if isinstance(function, dict):
                if 'iamRoleStatements' in function:
                    stmts = function['iamRoleStatements']
                    if isinstance(stmts, list):
                        for stmt in stmts:
                            if isinstance(stmt, dict):
                                actions = stmt['Action']
                                if isinstance(actions, list):
                                    for action in actions:
                                        permissions.add(action)
    elif isinstance(functions, list):
        # TODO resolve additional YML
        pass

def parse_roles(config, permissions):
    if 'resources' not in config:
        return

    resources = config['resources']
    if not isinstance(resources, dict):
        return

    if 'Resources' not in resources:
        return

    resources = resources['Resources']
    if not isinstance(resources, dict):
        return

    for resource_name, resource in resources.items():
        if not isinstance(resource, dict):
            continue

        if 'Type' not in resource:
            continue

        if resource['Type'] == 'AWS::IAM::Role':
            if 'Policies' in resource:
                for policy in resource['Policies']:
                    try:
                        stmts = policy['PolicyDocument']['Statement']
                        if isinstance(stmts, list):
                            for stmt in stmts:
                                actions = stmt['Action']
                                if isinstance(actions, list):
                                    for action in actions:
                                        permissions.add(action)
                    except KeyError:
                        pass


def process_project(project_path):
    global total_count
    permissions = set()

    for path in Path(project_path).rglob('*serverless*.y*ml'):
        total_count += 1

        with open(path, 'r') as file:
            try:
                config = yaml.safe_load(file)
                if not isinstance(config, dict):
                    continue

                parse_provider(config, permissions)
                parse_functions(config, permissions)
                parse_roles(config, permissions)
            except yaml.constructor.ConstructorError:
                continue
            except yaml.scanner.ScannerError:
                continue
            except yaml.composer.ComposerError:
                continue
            except yaml.parser.ParserError:
                continue
            except Exception as e:
                print(traceback.format_exc())
                continue

    return permissions

if __name__ == '__main__':
    users = [f.path for f in os.scandir('/data/serverless-dataset') if f.is_dir()]
    projects = []
    for user in users:
        projects += [f.path for f in os.scandir(user) if f.is_dir()]

    # print('{} Projects found.'.format(len(projects)))

    permissions = {}

    for project in projects:
        project_permissions = process_project(project)

        for permission in project_permissions:
            if permission not in permissions:
                permissions[permission] = 0

            permissions[permission] += 1

    # print('{} candidate ymls found.'.format(total_count))

    df = pd.DataFrame(list(permissions.items()), columns=['Permission', 'Count'])

# %% [markdown]
# # Count of Permissions Used in Projects

# %%
pd.set_option('display.max_rows', 600)
df.sort_values('Count', ascending=False)
# Out:
#                                             Permission  Count
# 25                                    dynamodb:PutItem    220
# 6                                     dynamodb:GetItem    197
# 27                                       dynamodb:Scan    171
# 2                                       dynamodb:Query    169
# 1                                  dynamodb:UpdateItem    166
# 19                                 dynamodb:DeleteItem    160
# 4                                         s3:PutObject     96
# 21                                        s3:GetObject     91
# 58                              dynamodb:DescribeTable     75
# 17                               lambda:InvokeFunction     75
# 46                                                s3:*     69
# 22                                       s3:ListBucket     63
# 132                                         dynamodb:*     50
# 18                             dynamodb:BatchWriteItem     32
# 36                                     s3:PutObjectAcl     31
# 11                                   logs:PutLogEvents     30
# 14                                logs:CreateLogStream     30
# 20                                 logs:CreateLogGroup     30
# 140                                    sqs:SendMessage     27
# 32                                       ses:SendEmail     25
# 13                                     s3:DeleteObject     25
# 42                                         sns:Publish     25
# 134                              xray:PutTraceSegments     21
# 133                           xray:PutTelemetryRecords     21
# 9                                dynamodb:BatchGetItem     20
# 101                                  kinesis:PutRecord     19
# 148                      ec2:DescribeNetworkInterfaces     19
# 16                                dynamodb:ListStreams     19
# 129                                   ssm:GetParameter     18
# 10                             dynamodb:DescribeStream     18
# 149                         ec2:DeleteNetworkInterface     18
# 8                                   lambda:InvokeAsync     18
# 147                         ec2:CreateNetworkInterface     17
# 105                                              sqs:*     17
# 96                                        iam:PassRole     17
# 3                            dynamodb:GetShardIterator     17
# 174                           cloudwatch:PutMetricData     16
# 178                                 sqs:ReceiveMessage     16
# 176                                  sqs:DeleteMessage     16
# 5                                  dynamodb:GetRecords     16
# 99                                               sns:*     16
# 195                                    sqs:GetQueueUrl     13
# 43                                    ses:SendRawEmail     13
# 121                                        kms:Decrypt     12
# 144                      execute-api:ManageConnections     11
# 236                                             logs:*     11
# 26                            rekognition:DetectLabels     10
# 33                               ec2:DescribeInstances     10
# 181                                  ssm:GetParameters      9
# 159                              states:StartExecution      9
# 139                                 kinesis:PutRecords      8
# 173                      secretsmanager:GetSecretValue      8
# 145                                       cloudwatch:*      8
# 158                                        KMS:Decrypt      7
# 142                                      rekognition:*      7
# 44                                         SNS:Publish      7
# 183                         ec2:DetachNetworkInterface      7
# 138                                       es:ESHttpGet      6
# 103                                       s3:getObject      6
# 110                                 kinesis:GetRecords      6
# 117                                dynamodb:ListTables      6
# 71                                dynamodb:CreateTable      6
# 155                                                  *      6
# 157                                              ses:*      6
# 177                                     sqs:ListQueues      6
# 168                                 firehose:PutRecord      6
# 198                                     ec2:CreateTags      6
# 137                                      es:ESHttpPost      5
# 230                                      ec2:Describe*      5
# 68                                       sns:Subscribe      5
# 184                                           s3:List*      5
# 37                             rekognition:DetectFaces      5
# 188                                            s3:Get*      5
# 34                                     s3:GetObjectAcl      5
# 274                                    s3:CreateBucket      5
# 226                          cloudwatch:PutMetricAlarm      5
# 114                                     sts:AssumeRole      5
# 77                       cloudfront:CreateInvalidation      5
# 321                                        iot:Publish      5
# 408                                              ec2:*      5
# 131                                   ssm:PutParameter      4
# 31                                  ec2:DeleteSnapshot      4
# 406                             sqs:GetQueueAttributes      4
# 189                                  ec2:StopInstances      4
# 29                                  ec2:DescribeImages      4
# 187                                 ec2:StartInstances      4
# 216                                        iam:GetRole      4
# 104                                       s3:putObject      4
# 111                           kinesis:GetShardIterator      4
# 106                                kinesis:ListStreams      4
# 107                             kinesis:DescribeStream      4
# 102                                     apigateway:GET      4
# 108                                           lambda:*      4
# 163                                              ecs:*      4
# 224                                      rds:Describe*      4
# 47                                dynamodb:UpdateTable      4
# 209                                   events:PutEvents      4
# 294                     cloudwatch:GetMetricStatistics      4
# 324                                kms:GenerateDataKey      4
# 175                                              iot:*      4
# 297                          cloudwatch:DescribeAlarms      4
# 79                                     apigateway:POST      4
# 115                               iot:DescribeEndpoint      4
# 361                    lambda:GetFunctionConfiguration      4
# 154                                      s3:HeadObject      4
# 237                               lambda:ListFunctions      4
# 165                                 ce:GetCostAndUsage      4
# 470                                       S3:GetObject      3
# 162                               iam:DeleteRolePolicy      3
# 257                            rds:DescribeDBInstances      3
# 126                  dynamodb:DescribeReservedCapacity      3
# 191                                        ecs:RunTask      3
# 141                                       es:ESHttpPut      3
# 143                                    es:ESHttpDelete      3
# 233                               ecs:DescribeClusters      3
# 150                                    sns:CreateTopic      3
# 153                            firehose:PutRecordBatch      3
# 238                                              SNS:*      3
# 120                   route53:ChangeResourceRecordSets      3
# 100                                           athena:*      3
# 118         dynamodb:DescribeReservedCapacityOfferings      3
# 391                                            s3:Put*      3
# 386                                            polly:*      3
# 69                                        apigateway:*      3
# 397                            translate:TranslateText      3
# 314                                      ecs:ListTasks      3
# 317                                      iot:Subscribe      3
# 319                                        iot:Connect      3
# 320                                        iot:Receive      3
# 326                                      cognito-idp:*      3
# 48                                dynamodb:DeleteTable      3
# 333                                     ec2:DeleteTags      3
# 40                                 s3:PutObjectTagging      3
# 334                            rds:ListTagsForResource      3
# 30                                 ec2:DeregisterImage      3
# 343                 lambda:UpdateFunctionConfiguration      3
# 15                              rekognition:IndexFaces      3
# 83                            cognito-idp:AdminGetUser      3
# 199                                   ec2:DescribeTags      3
# 97                          cloudformation:DeleteStack      3
# 91                                s3:GetBucketLocation      3
# 98                                              glue:*      3
# 92                          cloudformation:CreateStack      3
# 201                           sagemaker:InvokeEndpoint      3
# 109                                 cognito-identity:*      3
# 112                                         sdb:Select      3
# 287                                iam:DeleteAccessKey      2
# 223                         cloudformation:GetTemplate      2
# 259                                 s3:PutBucketPolicy      2
# 322                              iot:UpdateThingShadow      2
# 327                              rds:AddTagsToResource      2
# 372                                 ec2:CreateSnapshot      2
# 260         cloudformation:UpdateTerminationProtection      2
# 225                                       route53:Get*      2
# 331                         rds:RemoveTagsFromResource      2
# 335                                   ecs:ListServices      2
# 433                                     dynamodb:List*      2
# 232                               rds:ModifyDBInstance      2
# 337                               ecs:DescribeServices      2
# 270                             logs:DescribeLogGroups      2
# 340                                  ecs:UpdateService      2
# 273                         ec2:DescribeSecurityGroups      2
# 438                                 dynamodb:Describe*      2
# 441                        dynamodb:ConditionCheckItem      2
# 362                                    appsync:GraphQL      2
# 396                        cognito-idp:AdminCreateUser      2
# 208                         ses:SendBulkTemplatedEmail      2
# 207                             ses:SendTemplatedEmail      2
# 358                                        kms:Encrypt      2
# 231                                      route53:List*      2
# 234                            ecs:ListTagsForResource      2
# 318                                 iot:GetThingShadow      2
# 305                         cloudfront:GetDistribution      2
# 387                            logs:PutRetentionPolicy      2
# 292                             cloudwatch:ListMetrics      2
# 293                            cloudwatch:DeleteAlarms      2
# 295                 cloudwatch:DescribeAlarmsForMetric      2
# 414                                      elasticache:*      2
# 298                 xray:GetSamplingStatisticSummaries      2
# 299                              xray:GetSamplingRules      2
# 300                            xray:GetSamplingTargets      2
# 385                           cognito-sync:ListRecords      2
# 254                                    s3:PutBucketAcl      2
# 384                         cognito-sync:UpdateRecords      2
# 382                         ec2:ResetSnapshotAttribute      2
# 253                                     iam:DeleteRole      2
# 389                                      s3:PutObject*      2
# 413                                   ec2:RunInstances      2
# 306                                    sqs:CreateQueue      2
# 307                         ecs:ListContainerInstances      2
# 393                            ssm:GetParametersByPath      2
# 239                             polly:SynthesizeSpeech      2
# 380                                     lambda:Invoke*      2
# 310                                  ecs:DescribeTasks      2
# 311                     ecs:DescribeContainerInstances      2
# 395                     cognito-idp:AdminConfirmSignUp      2
# 377                        ec2:ModifySnapshotAttribute      2
# 316                                         firehose:*      2
# 281                                 s3:GetBucketPolicy      2
# 250                                 iam:ListAccessKeys      2
# 0                              logs:DescribeLogStreams      2
# 38                         s3:ListMultipartUploadParts      2
# 167                                             xray:*      2
# 453                                          rds:List*      2
# 76                    codepipeline:PutJobSuccessResult      2
# 39                       s3:ListBucketMultipartUploads      2
# 75                                            states:*      2
# 170                         firehose:UpdateDestination      2
# 169                      firehose:DeleteDeliveryStream      2
# 488                              lambda:DeleteFunction      2
# 78                    codepipeline:PutJobFailureResult      2
# 460                     elasticloadbalancing:Describe*      2
# 52                                     sns:Unsubscribe      2
# 130                                ssm:DeleteParameter      2
# 135                                           kendra:*      2
# 498                                          kinesis:*      2
# 146                                       codedeploy:*      2
# 185                                ec2:DescribeSubnets      2
# 156                                               es:*      2
# 88                          cloudformation:UpdateStack      2
# 87                       cloudformation:DescribeStacks      2
# 23                             rekognition:SearchFaces      2
# 197                              ec2:DescribeSnapshots      2
# 450                                     cognito-sync:*      2
# 472                                       S3:PutObject      2
# 113                                  sdb:PutAttributes      2
# 196                                    ec2:CreateImage      2
# 12                        rekognition:DeleteCollection      2
# 192                        sagemaker:CreateTrainingJob      2
# 24                        rekognition:CreateCollection      2
# 85               cognito-idp:AdminUpdateUserAttributes      2
# 490                           cloudwatch:SetAlarmState      1
# 388                             dynamodb:BatchReadItem      1
# 390                                    S3:PutObjectAcl      1
# 489                                       lambda:List*      1
# 491                                  ecs:CreateService      1
# 379               rds:ModifyDBClusterSnapshotAttribute      1
# 381                                      ec2:CopyImage      1
# 480       comprehend:DescribeDocumentClassificationJob      1
# 486                                      s3:GetObject*      1
# 487                                     s3:ListBucket*      1
# 481                           textract:AnalyzeDocument      1
# 485                             xray:GetTraceSummaries      1
# 383                          rds:CopyDBClusterSnapshot      1
# 484                                xray:BatchGetTraces      1
# 483                         logs:PutSubscriptionFilter      1
# 378                               rds:CreateDBSnapshot      1
# 478          comprehend:StartDocumentClassificationJob      1
# 479                                       transcribe:*      1
# 482                              Lambda:InvokeFunction      1
# 448                    cognito-idp:AdminAddUserToGroup      1
# 500                                  logs:GetLogEvents      1
# 492                                  ecs:CreateCluster      1
# 505                                      sqs:Describe*      1
# 357                                    sns:DeleteTopic      1
# 508                                            batch:*      1
# 359                            s3:PutBucketReplication      1
# 360                             sns:SetTopicAttributes      1
# 363                          kafka:GetBootstrapBrokers      1
# 364                              kafka:DescribeCluster      1
# 365                                      SNS:Subscribe      1
# 366                                   ec2:DescribeVpcs      1
# 367                         ec2:DescribeImageAttribute      1
# 507                                     rds-db:connect      1
# 368                                 rds:CopyDBSnapshot      1
# 369                           ec2:ModifyImageAttribute      1
# 506                                        sqs:Delete*      1
# 370                      rds:ModifyDBSnapshotAttribute      1
# 371                                   ec2:CopySnapshot      1
# 493                         ecs:DescribeTaskDefinition      1
# 504                       elasticloadbalancing:Delete*      1
# 503                                        rds:Delete*      1
# 373                        rds:CreateDBClusterSnapshot      1
# 374                        rds:DeleteDBClusterSnapshot      1
# 502                         elasticloadbalancing:List*      1
# 501                                          sqs:List*      1
# 375                                       sns:Publish*      1
# 376                               rds:DeleteDBSnapshot      1
# 476                  comprehend:DetectDominantLanguage      1
# 499                      lambda:ListVersionsByFunction      1
# 497                                  ecs:DeleteService      1
# 496                                      ecs:StartTask      1
# 495                         ecs:RegisterTaskDefinition      1
# 494                       ecs:DeregisterTaskDefinition      1
# 477                        comprehend:classifyDocument      1
# 399                  ecr:PutImageScanningConfiguration      1
# 392                     rekognition:SearchFacesByImage      1
# 457                                  kinesis:Describe*      1
# 455                                     tag:getTagKeys      1
# 430                            iam:DeletePolicyVersion      1
# 429                              iam:DeleteGroupPolicy      1
# 428                             elasticloadbalancing:*      1
# 355                  cloudformation:ListStackResources      1
# 456                                      kinesis:List*      1
# 427                                     lambda:Remove*      1
# 475                         comprehend:DetectSentiment      1
# 458                                   tag:getResources      1
# 459                                   tag:getTagValues      1
# 426                                           events:*      1
# 425                              elasticache:Describe*      1
# 424                           elasticloadbalancingv2:*      1
# 423                                         glue:Stop*      1
# 454                              autoscaling:Describe*      1
# 431                                   dynamodb:Delete*      1
# 432                        cloudformation:DeleteStack*      1
# 452                             sdb:batchPutAttributes      1
# 434                                      autoscaling:*      1
# 435                               iam:DetachRolePolicy      1
# 436                          application-autoscaling:*      1
# 451                             sdb:BatchPutAttributes      1
# 437                      cloudformation:DescribeStack*      1
# 439                                elasticache:Delete*      1
# 440                              dynamodb:CreateBackup      1
# 442                                      iam:ListRoles      1
# 449                                       iam:GetGroup      1
# 443                           iam:ListInstanceProfiles      1
# 444                                    batch:SubmitJob      1
# 445                 cognito-idp:DescribeUserPoolClient      1
# 446                               cognito-idp:GetGroup      1
# 422                                          route53:*      1
# 421                                       glue:Delete*      1
# 420                                     lambda:Delete*      1
# 467  arn:aws:iam::aws:policy/service-role/AWSLambda...      1
# 394                 cognito-idp:AdminListGroupsForUser      1
# 474                                ec2:DescribeVolumes      1
# 473                              s3:ListBucketVersions      1
# 398                           cloudwatch:GetMetricData      1
# 447                            cognito-idp:CreateGroup      1
# 400                                 ecr:DescribeImages      1
# 401                      ecr:DescribeImageScanFindings      1
# 471                                      S3:ListBucket      1
# 469                                       neptune-db:*      1
# 402                           ecr:DescribeRepositories      1
# 403                                 ecr:StartImageScan      1
# 468  arn:aws:iam::aws:policy/service-role/AWSLambda...      1
# 404                          ecr:GetAuthorizationToken      1
# 405                                     ecr:ListImages      1
# 407                                              ssm:*      1
# 419                                        lambda:Get*      1
# 466                                      s3:GetObject"      1
# 409                                    iot:CreateThing      1
# 410                                          ses:Send*      1
# 411                                    iot:DeleteThing      1
# 412                                    s3:DeleteBucket      1
# 465                                        translate:*      1
# 464                                     events:PutRule      1
# 463                                  events:DeleteRule      1
# 462                                  events:PutTargets      1
# 415                                 codepipeline:List*      1
# 416                                     codebuild:Get*      1
# 461                               events:RemoveTargets      1
# 417                                  codepipeline:Get*      1
# 418                                   iam:DeletePolicy      1
# 356                                   lambda:GetPolicy      1
# 255                    iam:UpdateAccountPasswordPolicy      1
# 354                             s3:PutBucketVersioning      1
# 160                           s3:PutBucketNotification      1
# 180               cloudformation:DescribeStackResource      1
# 179                                              waf:*      1
# 172                        dynamodb:DescribeTimeToLive      1
# 171                                 ce:GetCostForecast      1
# 166                           states:ListStateMachines      1
# 164                             iam:ListAccountAliases      1
# 161                                 execute-api:Invoke      1
# 152                            s3:AbortMultipartUpload      1
# 119                              route53:GetHostedZone      1
# 151                                     sns:ListTopics      1
# 136                   transcribe:StartTranscriptionJob      1
# 128                      cloudfront:UpdateDistribution      1
# 127                          dynamodb:UpdateTimeToLive      1
# 125                                  apigateway:DELETE      1
# 124                            route53:ListHostedZones      1
# 123                               acm:ListCertificates      1
# 182                                        kms:decrypt      1
# 186                              iam:ListGroupsForUser      1
# 190                         ec2:DescribeInstanceStatus      1
# 193                      sagemaker:DescribeTrainingJob      1
# 218                             states:SendTaskSuccess      1
# 217                           states:SendTaskHeartbeat      1
# 215                                          iam:List*      1
# 214                          elastictranscoder:*Preset      1
# 213                                          sns:List*      1
# 212                            elastictranscoder:List*      1
# 211                             elastictranscoder:*Job      1
# 210                            elastictranscoder:Read*      1
# 206                              lambda:invokeFunction      1
# 205                                          s3:upload      1
# 204                     sagemaker:CreateEndpointConfig      1
# 203                           sagemaker:CreateEndpoint      1
# 202                              sagemaker:CreateModel      1
# 200                                         rds-data:*      1
# 194                             sqs:DeleteMessageBatch      1
# 122                            dynamodb:DescribeLimits      1
# 116                     route53:ListResourceRecordSets      1
# 220                             states:SendTaskFailure      1
# 53                          dynamodb:CreateGlobalTable      1
# 61   cloudfront:GetCloudFrontOriginAccessIdentityCo...      1
# 60     cloudfront:UpdateCloudFrontOriginAccessIdentity      1
# 59                        dynamodb:DescribeGlobalTable      1
# 57              elasticloadbalancing:DeregisterTargets      1
# 56                         iam:CreateServiceLinkedRole      1
# 55                         ses:SetActiveReceiptRuleSet      1
# 54              elasticloadbalancing:ModifyTargetGroup      1
# 51              elasticloadbalancing:CreateTargetGroup      1
# 95                       cloudformation:SetStackPolicy      1
# 50     cloudfront:CreateCloudFrontOriginAccessIdentity      1
# 49              elasticloadbalancing:DeleteTargetGroup      1
# 45                                     SNS:CreateTopic      1
# 41                          s3:PutObjectVersionTagging      1
# 35                              s3:PutObjectVersionAcl      1
# 28                             rekognition:DeleteFaces      1
# 7                                rekognition:ListFaces      1
# 62                            ses:VerifyDomainIdentity      1
# 63     cloudfront:DeleteCloudFrontOriginAccessIdentity      1
# 64                          dynamodb:UpdateGlobalTable      1
# 65    elasticloadbalancing:ModifyTargetGroupAttributes      1
# 94                      cloudformation:DeleteChangeSet      1
# 93                      cloudformation:CreateChangeSet      1
# 90                     cloudformation:ExecuteChangeSet      1
# 89                    cloudformation:DescribeChangeSet      1
# 86                            cognito-idp:InitiateAuth      1
# 84                           cognito-idp:ConfirmSignUp      1
# 82                                         sns:publish      1
# 81                        cognito-idp:AdminDisableUser      1
# 80                                  cognito-idp:SignUp      1
# 74     cloudfront:ListCloudFrontOriginAccessIdentities      1
# 73                                dynamodb:TagResource      1
# 72                                  ses:DeleteIdentity      1
# 70        cloudfront:GetCloudFrontOriginAccessIdentity      1
# 67                         dynamodb:ListTagsOfResource      1
# 66                elasticloadbalancing:RegisterTargets      1
# 219                             states:GetActivityTask      1
# 221                           cloudformation:Describe*      1
# 353                              sns:ListSubscriptions      1
# 303                          iot:DetachPrincipalPolicy      1
# 323                                     mediaconvert:*      1
# 315                                    SQS:SendMessage      1
# 313                      ec2:DescribeInstanceAttribute      1
# 312                autoscaling:CompleteLifecycleAction      1
# 309                     ecs:SubmitContainerStateChange      1
# 308                  ecs:UpdateContainerInstancesState      1
# 304                                              ecr:*      1
# 302                                   iot:CreatePolicy      1
# 284                                   iam:ListPolicies      1
# 301                          iot:AttachPrincipalPolicy      1
# 296                    cloudwatch:DescribeAlarmHistory      1
# 291                                ec2:AllocateAddress      1
# 290                                 ec2:ReleaseAddress      1
# 289                                         s3:*Object      1
# 288                                    kms:CreateAlias      1
# 286                              kms:EnableKeyRotation      1
# 325                             ssm:DescribeParameters      1
# 328                             autoscaling:DeleteTags      1
# 329                                rds:StartDBInstance      1
# 330                     autoscaling:CreateOrUpdateTags      1
# 352              ses:GetIdentityVerificationAttributes      1
# 351                      CloudFormation:DescribeStacks      1
# 350                               lambda:AddPermission      1
# 349                                s3:ListAllMyBuckets      1
# 348                       sns:ListSubscriptionsByTopic      1
# 347                                         textract:*      1
# 346                      cloudfront:updateDistribution      1
# 345                             sns:GetTopicAttributes      1
# 344                                  sns:AddPermission      1
# 342                                 rds:StopDBInstance      1
# 341              autoscaling:DescribeAutoScalingGroups      1
# 339                                  ecs:UntagResource      1
# 338                                    ecs:TagResource      1
# 336                                   ecs:ListClusters      1
# 332                 autoscaling:UpdateAutoScalingGroup      1
# 285                            iam:CreatePolicyVersion      1
# 283                                      iam:GetPolicy      1
# 222                rds:RestoreDBInstanceFromDBSnapshot      1
# 244                                   DynamoDB:GetItem      1
# 252                             cloudtrail:UpdateTrail      1
# 251                                      kms:CreateKey      1
# 249                                  iam:PutRolePolicy      1
# 248                      ec2:RevokeSecurityGroupEgress      1
# 247                                iam:GetLoginProfile      1
# 246                                DynamoDB:UpdateItem      1
# 245                                     DynamoDB:Query      1
# 243                                   DynamoDB:PutItem      1
# 282                                      iam:ListUsers      1
# 242                                      DynamoDB:Scan      1
# 241                                DynamoDB:DeleteItem      1
# 240                                     SNS:ListTopics      1
# 235                                 lambda:ListAliases      1
# 229                               rds:CreateDBInstance      1
# 228                    cloudformation:ValidateTemplate      1
# 227                               rds:DeleteDBInstance      1
# 256                                logs:DeleteLogGroup      1
# 258                               iam:DetachUserPolicy      1
# 261                           iam:GetAccessKeyLastUsed      1
# 262                            config:DeleteConfigRule      1
# 280                          cloudformation:ListStacks      1
# 279                                 ec2:CreateFlowLogs      1
# 278                     ec2:RevokeSecurityGroupIngress      1
# 277                            kms:ScheduleKeyDeletion      1
# 276                               iam:GetPolicyVersion      1
# 275                              sts:GetCallerIdentity      1
# 272                      s3:PutEncryptionConfiguration      1
# 271                      s3:GetBucketPublicAccessBlock      1
# 269                                s3:PutBucketLogging      1
# 268                             iam:DeleteLoginProfile      1
# 267                               config:PutConfigRule      1
# 266                       iam:ListAttachedUserPolicies      1
# 265                                    kms:DeleteAlias      1
# 264                      s3:PutBucketPublicAccessBlock      1
# 263                                     iam:CreateRole      1
# 509                                    kms:ListAliases      1

# %% [markdown]
# # Service Permissions Used

# %%
tmp = df['Permission'].str.split(':', n=1, expand=True)
tmp = tmp.rename(columns={0: 'Service', 1: 'Action'})
tmp['Service'] = tmp['Service'].str.lower()
tmp['Action'] = tmp['Action'].str.lower()
pd.set_option('display.max_rows', 100)
tmp.groupby('Service').size().sort_values(ascending=False)
# Out:
# Service
# s3                         44
# dynamodb                   40
# ec2                        36
# iam                        30
# ecs                        23
# rds                        21
# sns                        20
# cloudformation             19
# lambda                     18
# cognito-idp                14
# sqs                        13
# iot                        13
# kms                        11
# cloudwatch                 11
# logs                       10
# rekognition                10
# cloudfront                 10
# ses                        10
# elasticloadbalancing       10
# kinesis                     9
# ecr                         8
# xray                        8
# route53                     7
# autoscaling                 7
# ssm                         7
# states                      7
# sagemaker                   6
# events                      6
# es                          5
# firehose                    5
# comprehend                  5
# elastictranscoder           4
# apigateway                  4
# codepipeline                4
# sdb                         4
# cognito-sync                3
# elasticache                 3
# glue                        3
# tag                         3
# translate                   2
# kafka                       2
# transcribe                  2
# textract                    2
# config                      2
# polly                       2
# sts                         2
# execute-api                 2
# arn                         2
# ce                          2
# batch                       2
# waf                         1
# athena                      1
# application-autoscaling     1
# appsync                     1
# rds-db                      1
# secretsmanager              1
# cloudtrail                  1
# codebuild                   1
# elasticloadbalancingv2      1
# rds-data                    1
# codedeploy                  1
# neptune-db                  1
# mediaconvert                1
# cognito-identity            1
# kendra                      1
# acm                         1
# *                           1
# dtype: int64

# %%
df[df['Permission'].str.contains('arn:')]#.groupby('Action').size().sort_values(ascending=False)
# Out:
#                                             Permission  Count
# 467  arn:aws:iam::aws:policy/service-role/AWSLambda...      1
# 468  arn:aws:iam::aws:policy/service-role/AWSLambda...      1
