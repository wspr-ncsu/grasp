# %%
#!/usr/bin/env python
import pandas as pd

df = pd.read_csv('../results/data.csv', index_col=False)
#df = pd.read_csv('/data/serverless-ac21/data.csv')

# %% [markdown]
# # Serverless Applications that define an IAM Policy
#
# 588 Applications

# %%
pd.set_option('display.max_rows', 20)
df[(df['YMLs with Global Policies'] + df['Functions with Policies'] > 0)]
# Out:
#                                                    Name  YMLs  Invalid YMLs  \
# 2           serverless-dataset/mbudm/fotopia-serverless     2             0
# 5                 serverless-dataset/iDVB/middy-reroute     1             0
# 6            serverless-dataset/lingrino/infra-personal     4             0
# 10                serverless-dataset/adieuadieu/retinal     1             0
# 15    serverless-dataset/nikgraf/serverless-framewor...     5             0
# ...                                                 ...   ...           ...
# 1633             serverless-dataset/faultline/faultline     1             0
# 1635         serverless-dataset/pact-foundation/pact-js     1             0
# 1638  serverless-dataset/AnomalyInnovations/serverle...     5             0
# 1640  serverless-dataset/AnomalyInnovations/serverle...     1             0
# 1648   serverless-dataset/vvgomes/serverless-restaurant     3             0
#
# ...

# %% [markdown]
# # Serverless Applications that define a global IAM Policy
# 543 Applications

# %%
df[(df['YMLs with Global Policies'] > 0) ]
# Out:
#                                                    Name  YMLs  Invalid YMLs  \
# 2           serverless-dataset/mbudm/fotopia-serverless     2             0
# 6            serverless-dataset/lingrino/infra-personal     4             0
# 10                serverless-dataset/adieuadieu/retinal     1             0
# 15    serverless-dataset/nikgraf/serverless-framewor...     5             0
# 21    serverless-dataset/darbio/serverless-oauth2-se...     3             0
# ...                                                 ...   ...           ...
# 1633             serverless-dataset/faultline/faultline     1             0
# 1635         serverless-dataset/pact-foundation/pact-js     1             0
# 1638  serverless-dataset/AnomalyInnovations/serverle...     5             0
# 1640  serverless-dataset/AnomalyInnovations/serverle...     1             0
# 1648   serverless-dataset/vvgomes/serverless-restaurant     3             0
#
# ...

# %% [markdown]
# # Serverless Applications that define function level IAM Policy
# 64 Applications

# %%
df[df['Functions with Policies'] > 0]
# Out:
#                                                    Name  YMLs  Invalid YMLs  \
# 5                 serverless-dataset/iDVB/middy-reroute     1             0
# 62         serverless-dataset/nikita-skobov/collabopath     3             0
# 126              serverless-dataset/serverless/examples   146             5
# 137    serverless-dataset/serverless/serverless-graphql     8             1
# 185   serverless-dataset/tobilg/aws-lambda-api-call-...     2             0
# ...                                                 ...   ...           ...
# 1525         serverless-dataset/trilom/sls-microservice     5             1
# 1570                 serverless-dataset/TobiahRex/nj2jp     1             0
# 1599  serverless-dataset/erezrokah/serverless-monito...     5             0
# 1615  serverless-dataset/fishbrain/codebuild-slack-n...     1             0
# 1618            serverless-dataset/bridgecrewio/checkov    19             1
#
# ...

# %% [markdown]
# # Serverless Applications that define both global and function level IAM Policy
# 19 applications

# %%
df[(df['Functions with Policies'] > 0) & (df['YMLs with Global Policies'] > 0)]
# Out:
#                                                    Name  YMLs  Invalid YMLs  \
# 126              serverless-dataset/serverless/examples   146             5
# 268      serverless-dataset/tyvdh/turing-signing-server     1             0
# 526          serverless-dataset/dailyidea/dailyidea.com     4             0
# 561      serverless-dataset/unfor19/serverless-template     6             1
# 572   serverless-dataset/serverless-operations/serve...     5             1
# 602                     serverless-dataset/diego3g/nivo     2             0
# 622   serverless-dataset/haftahave/serverless-ses-te...     3             1
# 767    serverless-dataset/matthewberryman/midsomerplots     1             0
# 809                 serverless-dataset/voteflux/THE-APP     1             0
# 846                  serverless-dataset/contentful/apps     4             0
# 933   serverless-dataset/dougmoscrop/serverless-plug...     2             0
# ...

# %% [markdown]
# # Functions that use iamStatements Plugin for function-level statements
# 22 Applications

# %%
df[df['Function Policy Version'] == 'iamStatements Plugin']
# Out:
#                                                    Name  YMLs  Invalid YMLs  \
# 185   serverless-dataset/tobilg/aws-lambda-api-call-...     2             0
# 268      serverless-dataset/tyvdh/turing-signing-server     1             0
# 364   serverless-dataset/SyamSundarKirubakaran/serve...     1             0
# 414                 serverless-dataset/a0viedo/slackper     1             0
# 535       serverless-dataset/servian/aws-auto-remediate     1             0
# ...                                                 ...   ...           ...
# 1522             serverless-dataset/manishbisht/Udacity     1             0
# 1525         serverless-dataset/trilom/sls-microservice     5             1
# 1570                 serverless-dataset/TobiahRex/nj2jp     1             0
# 1615  serverless-dataset/fishbrain/codebuild-slack-n...     1             0
# 1618            serverless-dataset/bridgecrewio/checkov    19             1
#
# ...

# %% [markdown]
# # Resources

# %%
df[df['Resources'] > 0]
# Out:
#                                                    Name  YMLs  Invalid YMLs  \
# 232       serverless-dataset/JetBrains/intellij-plugins     8             4
# 322      serverless-dataset/aws-cloudformation/cfn-lint     5             3
# 379              serverless-dataset/awslabs/goformation     9             5
# 381   serverless-dataset/awslabs/amazon-apigateway-i...     7             3
# 682   serverless-dataset/aws-samples/aws-service-cat...     5             3
# 824             serverless-dataset/glassechidna/stackit     1             0
# 883   serverless-dataset/arawn/building-serverless-a...     1             0
# 936             serverless-dataset/moduspwnens/boa-chat     1             0
# 1017    serverless-dataset/shalupov/idea-cloudformation     8             4
# 1203           serverless-dataset/MaxSecurity/BiliExper     2             0
# 1220  serverless-dataset/PacktPublishing/Hands-On-Se...     1             0
# ...

# %% [markdown]
# # Visualizations

# %%
df[df['Number of Function Statements'] > 0].hist(column='Number of Function Statements')
# Out:
# array([[<AxesSubplot:title={'center':'Number of Function Statements'}>]],
#       dtype=object)

# %%
df[df['Number of Function Statements'] > 0].hist(column='Number of Function Statements')
# Out:
# array([[<AxesSubplot:title={'center':'Number of Function Statements'}>]],
#       dtype=object)
